# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Stats.csv')
df.head()
# Out:
#    Unnamed: 0  gen  max_speed_indi  max_matSelectionProb_indi  \
# 0           0    1               8                       0.60
# 1           1    2               8                       0.65
# 2           2    3               4                       0.50
# 3           3    4               4                       0.50
#
#    max_vision_indi  avg_speed_indi  avg_matSelectionProb_indi  \
# 0               20        2.983871                   0.502742
# 1               20        3.166667                   0.508333
# 2               20        2.928571                   0.491429
# 3               20        2.250000                   0.487500
#
#    avg_vision_indi  population_indi  max_speed_pred  \
# 0        15.338710               62               3
# 1        15.900000               30               5
# 2        16.571429               14               4
# 3        17.250000                4               4
#
#    max_matSelectionProb_pred  max_vision_pred  avg_speed_pred  \
# ...

# %%
plt.plot(df["gen"],df["avg_speed_indi"])
plt.plot(df["gen"],df["avg_speed_pred"])
plt.xlabel("Generation")
plt.ylabel("Speed")
plt.title("Avg_Speed Graph")
# Out:
# Text(0.5, 1.0, 'Avg_Speed Graph')

# %%
plt.plot(df["gen"],df["avg_vision_indi"])
plt.plot(df["gen"],df["avg_vision_pred"])
plt.xlabel("Generation")
plt.ylabel("Vision")
plt.title("Avg_vision Graph")
# Out:
# Text(0.5, 1.0, 'Avg_vision Graph')

# %%
plt.plot(df["gen"],df["avg_matSelectionProb_indi"])
plt.plot(df["gen"],df["avg_matSelectionProb_pred"])
plt.xlabel("Generation")
plt.ylabel("Vision")
plt.title("Avg_matSelectionProb Graph")
# Out:
# Text(0.5, 1.0, 'Avg_matSelectionProb Graph')
